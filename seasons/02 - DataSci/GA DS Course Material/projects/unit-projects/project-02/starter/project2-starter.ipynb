# %% [markdown]
# # Unit Project 2
#
# In this project, you will implement the exploratory analysis plan developed in Project 1. This will lay the groundwork for our our first modeling exercise in Project 3.

# %% [markdown]
# ## Step 1: Load the python libraries you will need for this project

# %%
# imports
from __future__ import division

import numpy as np
import pandas as pd
import statsmodels.api as sm
import pylab as pl

# %matplotlib inline
import matplotlib.pyplot as plt

# %% [markdown]
# ## Step 2: Read in your data set

# %%
# Read in data from source
df_raw = pd.read_csv("../../../../data/admissions.csv")
print(df_raw.head())
# Out:
#    admit    gre   gpa  prestige
# 0      0  380.0  3.61       3.0
# 1      1  660.0  3.67       3.0
# 2      1  800.0  4.00       1.0
# 3      1  640.0  3.19       4.0
# 4      0  520.0  2.93       4.0

# %% [markdown]
# ## Questions
# ### Question 1. How many observations are in our dataset?

# %%
df_raw.count()
# Out:
# admit       400
# gre         398
# gpa         398
# prestige    399
# dtype: int64

# %%
df_raw.shape
# Out:
# (400, 4)

# %% [markdown]
# Answer: ? 400 observation with four categories

# %% [markdown]
# ### Question 2. Create a summary table

# %%
# <Code Here>
df_raw.describe()
# Out:
#             admit         gre        gpa    prestige
# count  400.000000  398.000000  398.00000  399.000000
# mean     0.317500  588.040201    3.39093    2.486216
# std      0.466087  115.628513    0.38063    0.945333
# min      0.000000  220.000000    2.26000    1.000000
# 25%      0.000000  520.000000    3.13000    2.000000
# 50%      0.000000  580.000000    3.39500    2.000000
# 75%      1.000000  660.000000    3.67000    3.000000
# max      1.000000  800.000000    4.00000    4.000000

# %%
# <Code Here>
df_raw.dtypes
# Out:
# admit         int64
# gre         float64
# gpa         float64
# prestige    float64
# dtype: object

# %%
df_raw.hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f53615fbd90>,
# ...
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f5361340410>]], dtype=object)

# %% [markdown]
# ### Question 3. Why would `GRE` have a larger SD than `GPA`?

# %% [markdown]
# Answer: ? they use different units of measurement

# %% [markdown]
# ### Question 4. Drop data points with missing data

# %%
# This is a complete guess  I may need assistance here
print pd.crosstab(df_raw['admit'], df_raw['prestige'], rownames=['admit'])
# Out:
# prestige  1.0  2.0  3.0  4.0
# admit
# 0          28   97   93   55
# 1          33   53   28   12

# %% [markdown]
# ### Question 5. Confirm that you dropped the correct data. How can you tell?

# %% [markdown]
# Answer: ?

# %% [markdown]
# ### Question 6. Create box plots for `GRE` and `GPA`

# %%
# boxplot 1
# <Code Here>
df_raw[["gre"]].plot(kind= "box")
plt.show()

# %%
# boxplot 2
# <Code Here>
# <Code Here>
df_raw[["gpa"]].plot(kind= "box")
plt.show()

# %% [markdown]
# ### Question 7. What do this plots show?

# %% [markdown]
# Answer: ? we can see outliner information

# %% [markdown]
# ### Question 8. Describe each distribution

# %%
# plot the distribution of each variable
# <Code Here>
df_raw["gre"].plot()
plt.show()
df_raw["gpa"].plot()
plt.show()

# %%
df_raw.plot(kind = "gre")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-37-ddda6940c981> in <module>()
# ----> 1 df_raw.plot(kind = "gre")
#
# /home/mactzu/anaconda2/lib/python2.7/site-packages/pandas/tools/plotting.pyc in __call__(self, x, y, kind, ax, subplots, sharex, sharey, layout, figsize, use_index, title, grid, legend, style, logx, logy, loglog, xticks, yticks, xlim, ylim, rot, fontsize, colormap, table, yerr, xerr, secondary_y, sort_columns, **kwds)
#    3772                           fontsize=fontsize, colormap=colormap, table=table,
#    3773                           yerr=yerr, xerr=xerr, secondary_y=secondary_y,
# -> 3774                           sort_columns=sort_columns, **kwds)
#    3775     __call__.__doc__ = plot_frame.__doc__
#    3776
#
# ...

# %% [markdown]
# ### Question 9. If our model had an assumption of a normal distribution would we meet that requirement?

# %% [markdown]
# Answer: ?

# %% [markdown]
# ### Question 10. Does this distribution need correction? If so, why? How?

# %% [markdown]
# Ansswer: ?

# %% [markdown]
# ### Question 11. Which of our variables are potentially colinear?

# %%
# create a correlation matrix for the data
# <Code Here>

# %% [markdown]
# ### Question 12. What did you find?

# %% [markdown]
# Answer: ?

# %% [markdown]
# ### Question 13. Write an analysis plan for exploring the association between grad school admissions rates and prestige of undergraduate schools.

# %% [markdown]
# Answer: ?

# %% [markdown]
# ### Question 14. What is your hypothesis?

# %% [markdown]
# Answer: ?

# %% [markdown]
# ## Bonus/Advanced

# %% [markdown]
# ### 1. Bonus: Explore alternatives to dropping observations with missing data

# %% [markdown]
# ### 2. Bonus: Log transform the skewed data

# %% [markdown]
# ### 3. Advanced: Impute missing data
